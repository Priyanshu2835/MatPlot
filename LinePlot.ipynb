# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanshu2835/MatPlot/blob/main/LinePlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(12,5))
x=["January","February","March","April","May","June","July","August","September","October","November","December"]
y=[5,7,9,13,17,21,26,29,31,20,13,8]
plt.xlabel("Months",fontsize=15)
plt.ylabel("Temperature (°C)",fontsize=15)
plt.title("Monthly Temperature chart",fontsize=20)
plt.plot(x,y,marker=".",label="Temperature (°C)")
plt.grid(alpha=.4)
plt.legend()
plt.show()
